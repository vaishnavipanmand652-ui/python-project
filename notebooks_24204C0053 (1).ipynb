# %%
print("vaishnavi")
# Out:
# vaishnavi

# %%
r1=5
r2=5
rs=r1+r2
print("Rs=",rs)
# Out:
# Rs= 10

# %%
r1=5
r2=5
rp=1/((1/r1)+(1/r2))
print("Rp=",rp)
# Out:
# Rp= 2.5

# %%
i=float(input("i="))
r=float(input ("r="))
v=i*r
print("voltage",v)
# Out:
# i= 5
# r= 5
# voltage 25.0

# %%
R1 = float(input"R1: "))
R2 = float(input"R2: "))
Rs = R1 + R2
print(Rs)
# Out:
#   Cell In[9], line 1
#     R1 = float(input"R1: "))
#                            ^
# SyntaxError: unmatched ')'

# %%
R1 = float(input"R1: "))
R2 = float(input"R2: "))
Rs = R1 + R2
print(Rs)
# Out:
#   Cell In[10], line 1
#     R1 = float(input"R1: "))
#                            ^
# SyntaxError: unmatched ')'

# %%
R1 = float(input"(R1: "))
R2 = float(input"(R2: "))
Rs = R1 + R2
print(Rs)
# Out:
#   Cell In[11], line 1
#     R1 = float(input"(R1: "))
#                             ^
# SyntaxError: unmatched ')'

# %%
R1 = float(input("R1: "))
R2 = float(input("R2: "))
Rs = R1 + R2
print(Rs)
# Out:
# R1:  5
# R2:  5
# 10.0

# %%
I = float(input("I: "))
R = float(input("R: "))
V=I*R
print("Voltage",v)
# Out:
# I:  5
# R:  5
# Voltage 25.0
